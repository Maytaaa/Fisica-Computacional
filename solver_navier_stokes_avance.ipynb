# %%
#Empezamos inicializando los parametros (fisicos, numericos, de borde y de estabilizacion) a usar en el problema. Partiendo por el problema de la caja cuadrada
#Se sigue la metodologia usada en "Numerical Simulations in Fluid Dynamics" de M. Griebel en el capitulo 3 "The Numerical Treatment of the Navier—Stokes Equations"
import numpy as np
import matplotlib.pyplot as plt
import nt

# Parámetros físicos
Lx, Ly = 1.0, 1.0   
rho = 1.0           
Re = 100.0          
nu = 1.0 / Re       

# Parámetros numéricos 
imax, jmax = 40, 40 
dx = Lx / imax
dy = Ly / jmax
dt = 0.001         

# Estabilización y convergencia para poisson
gamma = 0.9         # Factor de mezcla Upwind/Central, para cuando terminos convectivos sean dominantes a Re altos
omega = 1.7         
eps = 0.001         
iter_max = 100

# %%
#inicializamos los campos de velocidad, presión y el término fuente para la ecuación de Poisson. Se usan dimensiones ligeramente mayores para acomodar las condiciones de frontera usando "celdas fantamas"

u = np.zeros((imax + 1, jmax + 2)) # vive en las paredes verticales de la malla, por eso para imax cuadros de la malla hay imax+1 caras verticales
v = np.zeros((imax + 2, jmax + 1)) # lo opuesto a u, este vive en las caras horizontales
p = np.ones((imax + 2, jmax + 2))  # +2 en ambas dimensiones para acomodar las condiciones de frontera, u y v estan alineados en el eje y e x respectivamente a p. por ello tienen dimensiones j+2 e imax+2 respectivamente
rhs_poisson = np.zeros((imax + 2, jmax + 2)) # Término fuente para la ecuación de Poisson

# Términos intermedios (Predictor)
F = np.zeros((imax + 1, jmax + 2))
G = np.zeros((imax + 2, jmax + 1))

# %%
# Calculamos los terminos F (u estrella) y G (v estrella) de la etapa predictor usando diferencias finitas y aplicando la forma conservativa de las derivadas parciales para los terminos convectivos. 
# Se incluyen términos de difusión y convección, con mezcla Upwind/Central para estabilidad a Re altos.

def calcular_F_G(u, v, nu, dt, dx, dy, gamma, imax, jmax):
    # calculo de F
    for i in range(1, imax):
        for j in range(1, jmax + 1):
            # Derivadas de u^2 y uv (Forma Conservativa)
            # Promedios y diferencias para el transporte de momento en X
            du2dx = (1/dx) * ( ((u[i,j] + u[i+1,j])/2)**2 + gamma * abs(u[i,j] + u[i+1,j])/2 * (u[i,j] - u[i+1,j])/2 - 
                               ((u[i-1,j] + u[i,j])/2)**2 - gamma * abs(u[i-1,j] + u[i,j])/2 * (u[i-1,j] - u[i,j])/2 )
            
            duvdy = (1/dy) * ( ((v[i,j] + v[i+1,j])/2) * ((u[i,j] + u[i,j+1])/2) + gamma * abs(v[i,j] + v[i+1,j])/2 * (u[i,j] - u[i,j+1])/2 -
                               ((v[i,j-1] + v[i+1,j-1])/2) * ((u[i,j-1] + u[i,j])/2) - gamma * abs(v[i,j-1] + v[i+1,j-1])/2 * (u[i,j-1] - u[i,j])/2 )

            # Laplaciano de u (Difusión)
            lapl_u = (u[i+1,j] - 2*u[i,j] + u[i-1,j])/dx**2 + (u[i,j+1] - 2*u[i,j] + u[i,j-1])/dy**2
            
            F[i,j] = u[i,j] + dt * (nu * lapl_u - du2dx - duvdy)
    # calculo de G
    for i in range(1, imax + 1):
        for j in range(1, jmax):
            # Derivadas de uv y v^2 (Forma Conservativa)
            duvdx = (1/dx) * ( ((u[i,j] + u[i,j+1])/2) * ((v[i,j] + v[i+1,j])/2) + gamma * abs(u[i,j] + u[i,j+1])/2 * (v[i,j] - v[i+1,j])/2 -
                               ((u[i-1,j] + u[i-1,j+1])/2) * ((v[i-1,j] + v[i,j])/2) - gamma * abs(u[i-1,j] + u[i-1,j+1])/2 * (v[i-1,j] - v[i,j])/2 )
            
            dv2dy = (1/dy) * ( ((v[i,j] + v[i,j+1])/2)**2 + gamma * abs(v[i,j] + v[i,j+1])/2 * (v[i,j] - v[i,j+1])/2 -
                               ((v[i,j-1] + v[i,j])/2)**2 - gamma * abs(v[i,j-1] + v[i,j])/2 * (v[i,j-1] - v[i,j])/2 )

            # Laplaciano de v
            lapl_v = (v[i+1,j] - 2*v[i,j] + v[i-1,j])/dx**2 + (v[i,j+1] - 2*v[i,j] + v[i,j-1])/dy**2
            
            G[i,j] = v[i,j] + dt * (nu * lapl_v - duvdx - dv2dy)
    return F, G

# %%
# Con este campo de velocidades "estrella" u*=(F,G) nos es simple reconocer la descomposicion de Helmholtz-Hodge a usar para resolver nuestro problema (pag 33 del libro de M. Griebel)
# en done el campo solenoidal u^(n+1) se obtiene de la resta del campo (F,G) con el gradiente de un potencial escalar (la preison p). [u^(n+1) = u* - grad(p)]
# Luego aplicando la divergencia a la descomposicion obtenemos la ecuacion de Poisson para la presion, con el lado derecho dado por la divergencia de u*=(F,G). [lapl(p) = div(F,G) = rhs_poisson]
# definimos entonces la funcion para calcular el lado derecho de la ec de poisson

def calcular_rhs_poisson(F, G, dx, dt, dy, rho, imax, jmax):
    for i in range(1, imax + 1):
        for j in range(1, jmax + 1):
            rhs_poisson[i,j] = (rho / dt) * ( (F[i,j] - F[i-1,j])/dx + (G[i,j] - G[i,j-1])/dy )
    return rhs_poisson

# %%
# Con el lado derecho de la ec de poisson listo, ahora escribimos el lado izq (laplaciano) mediante diferencias finitas centradas y resolvemos la ecuacion de poisson para la presion usando
# el metodo iterativo de gauss-seidel con SOR para acelerar la convergencia. Para ello debemos despejar la presion p[i,j] en terminos de sus vecinos y el lado derecho rhs_poisson[i,j]. Imponemos condiciones de borde Neumann (dp/dn = 0).

def solver_poisson_SOR(p, rhs_poisson, dx, dy, omega, eps, iter_max, imax, jmax):
   
    p_viejo = np.zeros_like(p)
    dx2 = dx**2
    dy2 = dy**2
    denominador = 2.0 * (1.0/dx2 + 1.0/dy2)
    
    for it in range(iter_max):
        # Hacemos una copia para evaluar la convergencia al final de la iteración
        p_viejo[:, :] = p[:, :]
        residuo_max = 0.0
        
        # Recorremos los nodos internos
        for i in range(1, imax + 1):
            for j in range(1, jmax + 1):
                p_nuevo = (1.0 / denominador) * ( (p[i+1, j] + p[i-1, j]) / dx2 + (p[i, j+1] + p[i, j-1]) / dy2 - rhs_poisson[i, j] )

                #Aplicamos SOR
                p[i,j] = (1.0 - omega) * p[i,j] + omega * p_nuevo
                
                # Condición de Borde de Neumann (dp/dn = 0)
                if i == 1:       p[0, j] = p[1, j]         # Pared Izquierda
                if i == imax:    p[imax+1, j] = p[imax, j] # Pared Derecha
                if j == 1:       p[i, 0] = p[i, 1]         # Pared Inferior
                if j == jmax:    p[i, jmax+1] = p[i, jmax] # Pared Superior (Tapa)
                
        # Calculamos el error máximo (Residuo) en esta iteración
        # Se calcula restando la presión anterior a la recién iterada
        for i in range(1, imax + 1):
             for j in range(1, jmax + 1):
                  error_local = abs(p[i,j] - p_viejo[i,j])
                  if error_local > residuo_max:
                      residuo_max = error_local
        
        # Chequeo de convergencia
        if residuo_max < eps:
            #print(f"Poisson convergió en {it+1} iteraciones (Residuo: {residuo_max:.6f})")# lo comento pq tapa la pantalla, pero se puede decomentar para ver la convergencia
            return p
            
    print(f"ADVERTENCIA: Poisson NO convergió (Residuo: {residuo_max:.6f})")
    return p

# %%
# Finalmente, con la presion calculada, procedemos a actualizar los campos de velocidades solenoidales (correcion solenoidal) usando la relación u^(n+1) = u* - dt*grad(p)/rho. 
# Para esto, simplemente restamos el gradiente de la presión a los campos F y G para obtener las velocidades actualizadas u y v.

def corrector_solenoidal(u, v, F, G, p, dt, dx, dy, rho, imax, jmax):
    # Actualizamos u (Caras verticales: i=1..imax-1, j=1..jmax)
    for i in range(1, imax):
        for j in range(1, jmax + 1):
            # Gradiente de presión en X
            dp_dx = (p[i+1, j] - p[i, j]) / dx
            u[i, j] = F[i, j] - (dt / rho) * dp_dx
            
    # Actualizamos v (Caras horizontales: i=1..imax, j=1..jmax-1)
    for i in range(1, imax + 1):
        for j in range(1, jmax):
            # Gradiente de presión en Y
            dp_dy = (p[i, j+1] - p[i, j]) / dy
            v[i, j] = G[i, j] - (dt / rho) * dp_dy
            
    return u, v

# %%
# Con el campo de velocidades (u,v) corregido y listo para usar, planteamos las condiciones de borde para las situaciones pedidas.Partimos por las CB de la caja cuadrada, usando la condicion de no deslizamiento
# (no-slip condition, pag 30 del libro de M. Griebel), que establece 0 a las velocidades perpendiculaes a las poredes fijas y calcula el promedio de las velocidades tangenciales
# de modo que entre un paso antes y un paso despues de la pared, la velocidad tangencial sea 0. Para la tapa movil, se establece una velocidad tangencial constante (u=1) y se calcula el promedio con la velocidad del paso anterior para mantener la estabilidad.

def CB_cavidad_cuadrada(u, v, imax, jmax, u_tapa=1.0):
    # 1. Velocidades perpendiculares
    for j in range(1, jmax + 1):
        u[0, j] = 0.0          # Pared Izquierda
        u[imax, j] = 0.0       # Pared Derecha
        
    for i in range(1, imax + 1):
        v[i, 0] = 0.0          # Pared Inferior
        v[i, jmax] = 0.0       # Pared Superior
        
    # 2. Velocidades tangenciales (No slip)
    for j in range(1, jmax + 1):
        v[0, j] = -v[1, j]             # Promedio de v da 0 en la pared izquierda
        v[imax+1, j] = -v[imax, j]     # Promedio de v da 0 en la pared derecha

    for i in range(1, imax + 1):
        u[i, 0] = -u[i, 1]             # promedio de u da 0 en la pared inferior
        u[i, jmax+1] = 2.0*u_tapa - u[i, jmax] # promedio de u da u_tapa en la pared superior
        
    return u, v

# %%
# Con todo listo, ahora iniciamos el ciclo principal de la simulacion (para cavidad cuadrada) en donde se siguen los pasos del metodo de proyeccion de Chorin: 1- Imponer condiciones de borde, 2- Predictor (Calcular F y G),
# 3- Calcular lado derecho de Poisson, 4- Resolver Poisson para la presion, 5- Corrector Solenoidal y obtener el campo de velocidades real y actualizado para el siguiente paso de tiempo. Se monitorea el progreso cada ciertos pasos para no llenar la pantalla.
# dado que dt=0.001 y nt=10000, la simulacion avanzara hasta t=10 segundos, lo cual es suficiente para observar el desarrollo del flujo (se puede ajustar estos parametros para simular mas o menos tiempo segun se desee)

print(f"Iniciando simulación para Re = {Re}...")

# Parámetro para saber cada cuántos pasos imprimir en pantalla
pasos_impresion = 1000
nt = 10000

for n in range(nt):
    # 1-
    u, v = CB_cavidad_cuadrada(u, v, imax, jmax, u_tapa=1.0)
    
    # 2-
    F, G = calcular_F_G(u, v, nu, dt, dx, dy, gamma, imax, jmax)
    
    # 3-
    rhs_poisson = calcular_rhs_poisson(F, G, dx, dt, dy, rho, imax, jmax)
    
    # 4-
    p = solver_poisson_SOR(p, rhs_poisson, dx, dy, omega, eps, iter_max, imax, jmax)
    
    # 5-
    u, v = corrector_solenoidal(u, v, F, G, p, dt, dx, dy, rho, imax, jmax)
    
    # Monitoreo de progreso
    if n % pasos_impresion == 0:
        print(f"Paso de tiempo {n}/{nt} completado.")

print("¡Simulación terminada!")
# Out:
# Iniciando simulación para Re = 100.0...
# Poisson convergió en 3 iteraciones (Residuo: 0.000967)
# Paso de tiempo 0/10000 completado.
# Poisson convergió en 6 iteraciones (Residuo: 0.000873)
# Poisson convergió en 6 iteraciones (Residuo: 0.000992)
# Poisson convergió en 6 iteraciones (Residuo: 0.000945)
# Poisson convergió en 7 iteraciones (Residuo: 0.000820)
# Poisson convergió en 6 iteraciones (Residuo: 0.000931)
# Poisson convergió en 7 iteraciones (Residuo: 0.000708)
# Poisson convergió en 2 iteraciones (Residuo: 0.000905)
# Poisson convergió en 3 iteraciones (Residuo: 0.000797)
# Poisson convergió en 5 iteraciones (Residuo: 0.000729)
# Poisson convergió en 2 iteraciones (Residuo: 0.000658)
# Poisson convergió en 3 iteraciones (Residuo: 0.000808)
# Poisson convergió en 1 iteraciones (Residuo: 0.000668)
# Poisson convergió en 3 iteraciones (Residuo: 0.000669)
# Poisson convergió en 2 iteraciones (Residuo: 0.000929)
# Poisson convergió en 3 iteraciones (Residuo: 0.000867)
# Poisson convergió en 5 iteraciones (Residuo: 0.000927)
# Poisson convergió en 5 iteraciones (Residuo: 0.000967)
# Poisson convergió en 7 iteraciones (Residuo: 0.000625)
# Poisson convergió en 3 iteraciones (Residuo: 0.000990)
# Poisson convergió en 3 iteraciones (Residuo: 0.000843)
# Poisson convergió en 4 iteraciones (Residuo: 0.000965)
# Poisson convergió en 2 iteraciones (Residuo: 0.000922)
# Poisson convergió en 4 iteraciones (Residuo: 0.000893)
# Poisson convergió en 6 iteraciones (Residuo: 0.000883)
# Poisson convergió en 5 iteraciones (Residuo: 0.000998)
# Poisson convergió en 6 iteraciones (Residuo: 0.000988)
# Poisson convergió en 7 iteraciones (Residuo: 0.000840)
# Poisson convergió en 5 iteraciones (Residuo: 0.000829)
# Poisson convergió en 5 iteraciones (Residuo: 0.000570)
# Poisson convergió en 4 iteraciones (Residuo: 0.000956)
# Poisson convergió en 3 iteraciones (Residuo: 0.000904)
# Poisson convergió en 3 iteraciones (Residuo: 0.000704)
# Poisson convergió en 3 iteraciones (Residuo: 0.000859)
# Poisson convergió en 2 iteraciones (Residuo: 0.000671)
# Poisson convergió en 3 iteraciones (Residuo: 0.000728)
# Poisson convergió en 1 iteraciones (Residuo: 0.000724)
# Poisson convergió en 3 iteraciones (Residuo: 0.000774)
# Poisson convergió en 3 iteraciones (Residuo: 0.000887)
# Poisson convergió en 5 iteraciones (Residuo: 0.000901)
# Poisson convergió en 5 iteraciones (Residuo: 0.000867)
# Poisson convergió en 5 iteraciones (Residuo: 0.000757)
# Poisson convergió en 5 iteraciones (Residuo: 0.000576)
# Poisson convergió en 4 iteraciones (Residuo: 0.000928)
# Poisson convergió en 2 iteraciones (Residuo: 0.000940)
# Poisson convergió en 4 iteraciones (Residuo: 0.000676)
# Poisson convergió en 2 iteraciones (Residuo: 0.000935)
# Poisson convergió en 3 iteraciones (Residuo: 0.000942)
# Poisson convergió en 6 iteraciones (Residuo: 0.000917)
# Poisson convergió en 3 iteraciones (Residuo: 0.000984)
# Poisson convergió en 4 iteraciones (Residuo: 0.000817)
# Paso de tiempo 50/10000 completado.
# Poisson convergió en 5 iteraciones (Residuo: 0.000749)
# Poisson convergió en 5 iteraciones (Residuo: 0.000425)
# Poisson convergió en 2 iteraciones (Residuo: 0.000936)
# Poisson convergió en 3 iteraciones (Residuo: 0.000544)
# Poisson convergió en 1 iteraciones (Residuo: 0.000574)
# Poisson convergió en 1 iteraciones (Residuo: 0.000916)
# Poisson convergió en 2 iteraciones (Residuo: 0.000953)
# Poisson convergió en 4 iteraciones (Residuo: 0.000917)
# Poisson convergió en 5 iteraciones (Residuo: 0.000918)
# Poisson convergió en 4 iteraciones (Residuo: 0.000881)
# Poisson convergió en 4 iteraciones (Residuo: 0.000864)
# Poisson convergió en 3 iteraciones (Residuo: 0.000928)
# Poisson convergió en 4 iteraciones (Residuo: 0.000616)
# Poisson convergió en 3 iteraciones (Residuo: 0.000968)
# Poisson convergió en 6 iteraciones (Residuo: 0.000893)
# Poisson convergió en 6 iteraciones (Residuo: 0.000896)
# Poisson convergió en 6 iteraciones (Residuo: 0.000930)
# Poisson convergió en 6 iteraciones (Residuo: 0.000910)
# Poisson convergió en 4 iteraciones (Residuo: 0.000998)
# Poisson convergió en 4 iteraciones (Residuo: 0.000617)
# Poisson convergió en 4 iteraciones (Residuo: 0.000907)
# Poisson convergió en 2 iteraciones (Residuo: 0.000990)
# Poisson convergió en 3 iteraciones (Residuo: 0.000714)
# Poisson convergió en 4 iteraciones (Residuo: 0.000456)
# Poisson convergió en 3 iteraciones (Residuo: 0.000964)
# Poisson convergió en 2 iteraciones (Residuo: 0.000718)
# Poisson convergió en 3 iteraciones (Residuo: 0.000851)
# Poisson convergió en 5 iteraciones (Residuo: 0.000884)
# Poisson convergió en 5 iteraciones (Residuo: 0.000805)
# Poisson convergió en 5 iteraciones (Residuo: 0.000657)
# Poisson convergió en 1 iteraciones (Residuo: 0.000979)
# Poisson convergió en 3 iteraciones (Residuo: 0.000999)
# Poisson convergió en 2 iteraciones (Residuo: 0.000910)
# Poisson convergió en 3 iteraciones (Residuo: 0.000613)
# Poisson convergió en 3 iteraciones (Residuo: 0.000955)
# Poisson convergió en 2 iteraciones (Residuo: 0.000918)
# Poisson convergió en 3 iteraciones (Residuo: 0.000816)
# Poisson convergió en 5 iteraciones (Residuo: 0.000512)
# Poisson convergió en 3 iteraciones (Residuo: 0.000976)
# Poisson convergió en 4 iteraciones (Residuo: 0.000871)
# Poisson convergió en 6 iteraciones (Residuo: 0.000851)
# Poisson convergió en 6 iteraciones (Residuo: 0.000834)
# Poisson convergió en 5 iteraciones (Residuo: 0.000936)
# Poisson convergió en 4 iteraciones (Residuo: 0.000979)
# Poisson convergió en 4 iteraciones (Residuo: 0.000987)
# Poisson convergió en 6 iteraciones (Residuo: 0.000701)
# Poisson convergió en 4 iteraciones (Residuo: 0.000997)
# Poisson convergió en 2 iteraciones (Residuo: 0.000856)
# Poisson convergió en 2 iteraciones (Residuo: 0.000939)
# Poisson convergió en 2 iteraciones (Residuo: 0.000824)
# Paso de tiempo 100/10000 completado.
# Poisson convergió en 4 iteraciones (Residuo: 0.000798)
# Poisson convergió en 4 iteraciones (Residuo: 0.000981)
# Poisson convergió en 4 iteraciones (Residuo: 0.000926)
# Poisson convergió en 5 iteraciones (Residuo: 0.000682)
# Poisson convergió en 5 iteraciones (Residuo: 0.000423)
# Poisson convergió en 3 iteraciones (Residuo: 0.000935)
# Poisson convergió en 1 iteraciones (Residuo: 0.000995)
# Poisson convergió en 1 iteraciones (Residuo: 0.000778)
# Poisson convergió en 2 iteraciones (Residuo: 0.000686)
# Poisson convergió en 3 iteraciones (Residuo: 0.000899)
# Poisson convergió en 4 iteraciones (Residuo: 0.000839)
# Poisson convergió en 4 iteraciones (Residuo: 0.000738)
# Poisson convergió en 4 iteraciones (Residuo: 0.000850)
# Poisson convergió en 2 iteraciones (Residuo: 0.000875)
# Poisson convergió en 3 iteraciones (Residuo: 0.000541)
# Poisson convergió en 3 iteraciones (Residuo: 0.000983)
# Poisson convergió en 2 iteraciones (Residuo: 0.000901)
# Poisson convergió en 4 iteraciones (Residuo: 0.000892)
# Poisson convergió en 6 iteraciones (Residuo: 0.000778)
# Poisson convergió en 6 iteraciones (Residuo: 0.000757)
# Poisson convergió en 2 iteraciones (Residuo: 0.000754)
# Poisson convergió en 2 iteraciones (Residuo: 0.000970)
# Poisson convergió en 4 iteraciones (Residuo: 0.000890)
# Poisson convergió en 5 iteraciones (Residuo: 0.000963)
# Poisson convergió en 4 iteraciones (Residuo: 0.000933)
# Poisson convergió en 4 iteraciones (Residuo: 0.000923)
# Poisson convergió en 4 iteraciones (Residuo: 0.000899)
# Poisson convergió en 5 iteraciones (Residuo: 0.000975)
# Poisson convergió en 5 iteraciones (Residuo: 0.000885)
# Poisson convergió en 6 iteraciones (Residuo: 0.000605)
# Poisson convergió en 5 iteraciones (Residuo: 0.000702)
# Poisson convergió en 2 iteraciones (Residuo: 0.000948)
# Poisson convergió en 3 iteraciones (Residuo: 0.000859)
# Poisson convergió en 4 iteraciones (Residuo: 0.000738)
# Poisson convergió en 1 iteraciones (Residuo: 0.000922)
# Poisson convergió en 3 iteraciones (Residuo: 0.000991)
# Poisson convergió en 2 iteraciones (Residuo: 0.000964)
# Poisson convergió en 4 iteraciones (Residuo: 0.000447)
# Poisson convergió en 4 iteraciones (Residuo: 0.000768)
# Poisson convergió en 1 iteraciones (Residuo: 0.000754)
# Poisson convergió en 3 iteraciones (Residuo: 0.000874)
# Poisson convergió en 4 iteraciones (Residuo: 0.000868)
# Poisson convergió en 5 iteraciones (Residuo: 0.000874)
# Poisson convergió en 5 iteraciones (Residuo: 0.000840)
# Poisson convergió en 5 iteraciones (Residuo: 0.000770)
# Poisson convergió en 2 iteraciones (Residuo: 0.000895)
# Poisson convergió en 3 iteraciones (Residuo: 0.000680)
# Poisson convergió en 4 iteraciones (Residuo: 0.000622)
# Poisson convergió en 1 iteraciones (Residuo: 0.000700)
# Poisson convergió en 1 iteraciones (Residuo: 0.000973)
# Paso de tiempo 150/10000 completado.
# Poisson convergió en 2 iteraciones (Residuo: 0.000921)
# Poisson convergió en 3 iteraciones (Residuo: 0.000863)
# Poisson convergió en 5 iteraciones (Residuo: 0.000886)
# Poisson convergió en 6 iteraciones (Residuo: 0.000873)
# Poisson convergió en 6 iteraciones (Residuo: 0.000897)
# Poisson convergió en 5 iteraciones (Residuo: 0.000986)
# Poisson convergió en 6 iteraciones (Residuo: 0.000823)
# Poisson convergió en 6 iteraciones (Residuo: 0.000693)
# Poisson convergió en 2 iteraciones (Residuo: 0.000911)
# Poisson convergió en 3 iteraciones (Residuo: 0.000970)
# Poisson convergió en 1 iteraciones (Residuo: 0.000991)
# Poisson convergió en 3 iteraciones (Residuo: 0.000889)
# Poisson convergió en 1 iteraciones (Residuo: 0.000956)
# Poisson convergió en 3 iteraciones (Residuo: 0.000487)
# Poisson convergió en 3 iteraciones (Residuo: 0.000782)
# Poisson convergió en 3 iteraciones (Residuo: 0.000948)
# Poisson convergió en 4 iteraciones (Residuo: 0.000793)
# Poisson convergió en 5 iteraciones (Residuo: 0.000602)
# Poisson convergió en 4 iteraciones (Residuo: 0.000825)
# Poisson convergió en 4 iteraciones (Residuo: 0.000957)
# Poisson convergió en 5 iteraciones (Residuo: 0.000779)
# Poisson convergió en 5 iteraciones (Residuo: 0.000716)
# Poisson convergió en 5 iteraciones (Residuo: 0.000634)
# Poisson convergió en 2 iteraciones (Residuo: 0.000839)
# Poisson convergió en 3 iteraciones (Residuo: 0.000620)
# Poisson convergió en 3 iteraciones (Residuo: 0.000930)
# Poisson convergió en 2 iteraciones (Residuo: 0.000454)
# Poisson convergió en 1 iteraciones (Residuo: 0.000973)
# Poisson convergió en 2 iteraciones (Residuo: 0.000502)
# Poisson convergió en 1 iteraciones (Residuo: 0.000984)
# Poisson convergió en 3 iteraciones (Residuo: 0.000885)
# Poisson convergió en 6 iteraciones (Residuo: 0.000836)
# Poisson convergió en 4 iteraciones (Residuo: 0.000899)
# Poisson convergió en 5 iteraciones (Residuo: 0.000869)
# Poisson convergió en 5 iteraciones (Residuo: 0.000822)
# Poisson convergió en 5 iteraciones (Residuo: 0.000672)
# Poisson convergió en 2 iteraciones (Residuo: 0.000980)
# Poisson convergió en 3 iteraciones (Residuo: 0.000707)
# Poisson convergió en 4 iteraciones (Residuo: 0.000572)
# Poisson convergió en 2 iteraciones (Residuo: 0.000898)
# Poisson convergió en 3 iteraciones (Residuo: 0.000372)
# Poisson convergió en 1 iteraciones (Residuo: 0.000785)
# Poisson convergió en 2 iteraciones (Residuo: 0.000802)
# Poisson convergió en 1 iteraciones (Residuo: 0.000716)
# Poisson convergió en 2 iteraciones (Residuo: 0.000883)
# Poisson convergió en 4 iteraciones (Residuo: 0.000878)
# Poisson convergió en 6 iteraciones (Residuo: 0.000895)
# Poisson convergió en 6 iteraciones (Residuo: 0.000900)
# Poisson convergió en 5 iteraciones (Residuo: 0.000934)
# Poisson convergió en 6 iteraciones (Residuo: 0.000652)
# Paso de tiempo 200/10000 completado.
# Poisson convergió en 5 iteraciones (Residuo: 0.000772)
# Poisson convergió en 1 iteraciones (Residuo: 0.000987)
# Poisson convergió en 2 iteraciones (Residuo: 0.000947)
# Poisson convergió en 2 iteraciones (Residuo: 0.000918)
# Poisson convergió en 3 iteraciones (Residuo: 0.000890)
# Poisson convergió en 1 iteraciones (Residuo: 0.000881)
# Poisson convergió en 2 iteraciones (Residuo: 0.000931)
# Poisson convergió en 2 iteraciones (Residuo: 0.000866)
# Poisson convergió en 3 iteraciones (Residuo: 0.000748)
# Poisson convergió en 4 iteraciones (Residuo: 0.000875)
# Poisson convergió en 5 iteraciones (Residuo: 0.000990)
# Poisson convergió en 6 iteraciones (Residuo: 0.000867)
# Poisson convergió en 5 iteraciones (Residuo: 0.000918)
# Poisson convergió en 2 iteraciones (Residuo: 0.000949)
# Poisson convergió en 3 iteraciones (Residuo: 0.000993)
# Poisson convergió en 5 iteraciones (Residuo: 0.000581)
# Poisson convergió en 4 iteraciones (Residuo: 0.000881)
# Poisson convergió en 2 iteraciones (Residuo: 0.000905)
# Poisson convergió en 3 iteraciones (Residuo: 0.000801)
# Poisson convergió en 4 iteraciones (Residuo: 0.000525)
# Poisson convergió en 2 iteraciones (Residuo: 0.000922)
# Poisson convergió en 2 iteraciones (Residuo: 0.000928)
# Poisson convergió en 3 iteraciones (Residuo: 0.000996)
# Poisson convergió en 4 iteraciones (Residuo: 0.000855)
# Poisson convergió en 4 iteraciones (Residuo: 0.000945)
# Poisson convergió en 5 iteraciones (Residuo: 0.000901)
# Poisson convergió en 5 iteraciones (Residuo: 0.000871)
# Poisson convergió en 4 iteraciones (Residuo: 0.000856)
# Poisson convergió en 5 iteraciones (Residuo: 0.000693)
# Poisson convergió en 4 iteraciones (Residuo: 0.000993)
# Poisson convergió en 3 iteraciones (Residuo: 0.000788)
# Poisson convergió en 3 iteraciones (Residuo: 0.000492)
# Poisson convergió en 3 iteraciones (Residuo: 0.000680)
# Poisson convergió en 1 iteraciones (Residuo: 0.000773)
# Poisson convergió en 3 iteraciones (Residuo: 0.000582)
# Poisson convergió en 4 iteraciones (Residuo: 0.000481)
# Poisson convergió en 2 iteraciones (Residuo: 0.000978)
# Poisson convergió en 3 iteraciones (Residuo: 0.000653)
# Poisson convergió en 3 iteraciones (Residuo: 0.000955)
# Poisson convergió en 3 iteraciones (Residuo: 0.000980)
# Poisson convergió en 5 iteraciones (Residuo: 0.000857)
# Poisson convergió en 3 iteraciones (Residuo: 0.000993)
# Poisson convergió en 3 iteraciones (Residuo: 0.000613)
# Poisson convergió en 3 iteraciones (Residuo: 0.000921)
# Poisson convergió en 4 iteraciones (Residuo: 0.000780)
# Poisson convergió en 5 iteraciones (Residuo: 0.000708)
# Poisson convergió en 3 iteraciones (Residuo: 0.000965)
# Poisson convergió en 2 iteraciones (Residuo: 0.000982)
# Poisson convergió en 4 iteraciones (Residuo: 0.000587)
# Poisson convergió en 1 iteraciones (Residuo: 0.000739)
# Paso de tiempo 250/10000 completado.
# Poisson convergió en 3 iteraciones (Residuo: 0.000670)
# Poisson convergió en 1 iteraciones (Residuo: 0.000580)
# Poisson convergió en 1 iteraciones (Residuo: 0.000862)
# Poisson convergió en 3 iteraciones (Residuo: 0.000858)
# Poisson convergió en 5 iteraciones (Residuo: 0.000937)
# Poisson convergió en 6 iteraciones (Residuo: 0.000864)
# Poisson convergió en 5 iteraciones (Residuo: 0.000821)
# Poisson convergió en 5 iteraciones (Residuo: 0.000900)
# Poisson convergió en 5 iteraciones (Residuo: 0.000900)
# Poisson convergió en 2 iteraciones (Residuo: 0.000885)
# Poisson convergió en 4 iteraciones (Residuo: 0.000787)
# Poisson convergió en 3 iteraciones (Residuo: 0.000871)
# Poisson convergió en 3 iteraciones (Residuo: 0.000770)
# Poisson convergió en 4 iteraciones (Residuo: 0.000637)
# Poisson convergió en 4 iteraciones (Residuo: 0.000683)
# Poisson convergió en 3 iteraciones (Residuo: 0.000936)
# Poisson convergió en 2 iteraciones (Residuo: 0.000739)
# Poisson convergió en 3 iteraciones (Residuo: 0.000743)
# Poisson convergió en 2 iteraciones (Residuo: 0.000887)
# Poisson convergió en 2 iteraciones (Residuo: 0.000899)
# Poisson convergió en 4 iteraciones (Residuo: 0.000811)
# Poisson convergió en 4 iteraciones (Residuo: 0.000838)
# Poisson convergió en 5 iteraciones (Residuo: 0.000498)
# Poisson convergió en 2 iteraciones (Residuo: 0.000907)
# Poisson convergió en 3 iteraciones (Residuo: 0.000809)
# Poisson convergió en 1 iteraciones (Residuo: 0.000993)
# Poisson convergió en 4 iteraciones (Residuo: 0.000611)
# Poisson convergió en 4 iteraciones (Residuo: 0.000732)
# Poisson convergió en 1 iteraciones (Residuo: 0.000923)
# Poisson convergió en 3 iteraciones (Residuo: 0.000722)
# Poisson convergió en 3 iteraciones (Residuo: 0.000925)
# Poisson convergió en 3 iteraciones (Residuo: 0.000853)
# Poisson convergió en 4 iteraciones (Residuo: 0.000916)
# Poisson convergió en 5 iteraciones (Residuo: 0.000936)
# Poisson convergió en 4 iteraciones (Residuo: 0.000869)
# Poisson convergió en 5 iteraciones (Residuo: 0.000927)
# Poisson convergió en 4 iteraciones (Residuo: 0.000922)
# Poisson convergió en 4 iteraciones (Residuo: 0.000967)
# Poisson convergió en 4 iteraciones (Residuo: 0.000909)
# Poisson convergió en 3 iteraciones (Residuo: 0.000926)
# Poisson convergió en 4 iteraciones (Residuo: 0.000388)
# Poisson convergió en 3 iteraciones (Residuo: 0.000838)
# Poisson convergió en 1 iteraciones (Residuo: 0.000730)
# Poisson convergió en 1 iteraciones (Residuo: 0.000653)
# Poisson convergió en 1 iteraciones (Residuo: 0.000869)
# Poisson convergió en 2 iteraciones (Residuo: 0.000937)
# Poisson convergió en 4 iteraciones (Residuo: 0.000789)
# Poisson convergió en 5 iteraciones (Residuo: 0.000889)
# Poisson convergió en 4 iteraciones (Residuo: 0.000976)
# Poisson convergió en 4 iteraciones (Residuo: 0.000988)
# Paso de tiempo 300/10000 completado.
# Poisson convergió en 4 iteraciones (Residuo: 0.000940)
# Poisson convergió en 4 iteraciones (Residuo: 0.000899)
# Poisson convergió en 2 iteraciones (Residuo: 0.000899)
# Poisson convergió en 2 iteraciones (Residuo: 0.000781)
# Poisson convergió en 2 iteraciones (Residuo: 0.000990)
# Poisson convergió en 5 iteraciones (Residuo: 0.000804)
# Poisson convergió en 3 iteraciones (Residuo: 0.000901)
# Poisson convergió en 3 iteraciones (Residuo: 0.000784)
# Poisson convergió en 4 iteraciones (Residuo: 0.000617)
# Poisson convergió en 4 iteraciones (Residuo: 0.000590)
# Poisson convergió en 1 iteraciones (Residuo: 0.000637)
# Poisson convergió en 2 iteraciones (Residuo: 0.000940)
# Poisson convergió en 1 iteraciones (Residuo: 0.000975)
# Poisson convergió en 3 iteraciones (Residuo: 0.000973)
# Poisson convergió en 5 iteraciones (Residuo: 0.000988)
# Poisson convergió en 6 iteraciones (Residuo: 0.000963)
# Poisson convergió en 3 iteraciones (Residuo: 0.000795)
# Poisson convergió en 4 iteraciones (Residuo: 0.000921)
# Poisson convergió en 2 iteraciones (Residuo: 0.000894)
# Poisson convergió en 4 iteraciones (Residuo: 0.000979)
# Poisson convergió en 3 iteraciones (Residuo: 0.000853)
# Poisson convergió en 3 iteraciones (Residuo: 0.000971)
# Poisson convergió en 3 iteraciones (Residuo: 0.000937)
# Poisson convergió en 2 iteraciones (Residuo: 0.000967)
# Poisson convergió en 4 iteraciones (Residuo: 0.000736)
# Poisson convergió en 5 iteraciones (Residuo: 0.000588)
# Poisson convergió en 2 iteraciones (Residuo: 0.000843)
# Poisson convergió en 3 iteraciones (Residuo: 0.000600)
# Poisson convergió en 1 iteraciones (Residuo: 0.000899)
# Poisson convergió en 3 iteraciones (Residuo: 0.000908)
# Poisson convergió en 4 iteraciones (Residuo: 0.000827)
# Poisson convergió en 5 iteraciones (Residuo: 0.000571)
# Poisson convergió en 5 iteraciones (Residuo: 0.000784)
# Poisson convergió en 1 iteraciones (Residuo: 0.000952)
# Poisson convergió en 2 iteraciones (Residuo: 0.000910)
# Poisson convergió en 3 iteraciones (Residuo: 0.000791)
# Poisson convergió en 4 iteraciones (Residuo: 0.000720)
# Poisson convergió en 1 iteraciones (Residuo: 0.000764)
# Poisson convergió en 1 iteraciones (Residuo: 0.000945)
# Poisson convergió en 2 iteraciones (Residuo: 0.000657)
# Poisson convergió en 3 iteraciones (Residuo: 0.000785)
# Poisson convergió en 3 iteraciones (Residuo: 0.000869)
# Poisson convergió en 4 iteraciones (Residuo: 0.000935)
# Poisson convergió en 5 iteraciones (Residuo: 0.000806)
# Poisson convergió en 4 iteraciones (Residuo: 0.000900)
# Poisson convergió en 5 iteraciones (Residuo: 0.000960)
# Poisson convergió en 4 iteraciones (Residuo: 0.000905)
# Poisson convergió en 4 iteraciones (Residuo: 0.000617)
# Poisson convergió en 3 iteraciones (Residuo: 0.000915)
# Poisson convergió en 3 iteraciones (Residuo: 0.000891)
# Paso de tiempo 350/10000 completado.
# Poisson convergió en 4 iteraciones (Residuo: 0.000717)
# Poisson convergió en 4 iteraciones (Residuo: 0.000476)
# Poisson convergió en 2 iteraciones (Residuo: 0.000924)
# Poisson convergió en 2 iteraciones (Residuo: 0.000487)
# Poisson convergió en 2 iteraciones (Residuo: 0.000853)
# Poisson convergió en 2 iteraciones (Residuo: 0.000948)
# Poisson convergió en 4 iteraciones (Residuo: 0.000854)
# Poisson convergió en 5 iteraciones (Residuo: 0.000759)
# Poisson convergió en 2 iteraciones (Residuo: 0.000913)
# Poisson convergió en 4 iteraciones (Residuo: 0.000819)
# Poisson convergió en 4 iteraciones (Residuo: 0.000875)
# Poisson convergió en 4 iteraciones (Residuo: 0.000994)
# Poisson convergió en 5 iteraciones (Residuo: 0.000861)
# Poisson convergió en 2 iteraciones (Residuo: 0.000935)
# Poisson convergió en 3 iteraciones (Residuo: 0.000841)
# Poisson convergió en 1 iteraciones (Residuo: 0.000888)
# Poisson convergió en 3 iteraciones (Residuo: 0.000860)
# Poisson convergió en 1 iteraciones (Residuo: 0.000970)
# Poisson convergió en 3 iteraciones (Residuo: 0.000979)
# Poisson convergió en 3 iteraciones (Residuo: 0.000963)
# Poisson convergió en 4 iteraciones (Residuo: 0.000555)
# Poisson convergió en 3 iteraciones (Residuo: 0.000705)
# Poisson convergió en 3 iteraciones (Residuo: 0.000675)
# Poisson convergió en 1 iteraciones (Residuo: 0.000948)
# Poisson convergió en 3 iteraciones (Residuo: 0.000822)
# Poisson convergió en 4 iteraciones (Residuo: 0.000871)
# Poisson convergió en 4 iteraciones (Residuo: 0.000940)
# Poisson convergió en 4 iteraciones (Residuo: 0.000985)
# Poisson convergió en 2 iteraciones (Residuo: 0.000773)
# Poisson convergió en 3 iteraciones (Residuo: 0.000847)
# Poisson convergió en 4 iteraciones (Residuo: 0.000901)
# Poisson convergió en 4 iteraciones (Residuo: 0.000789)
# Poisson convergió en 3 iteraciones (Residuo: 0.000959)
# Poisson convergió en 3 iteraciones (Residuo: 0.000837)
# Poisson convergió en 3 iteraciones (Residuo: 0.000899)
# Poisson convergió en 5 iteraciones (Residuo: 0.000853)
# Poisson convergió en 4 iteraciones (Residuo: 0.000845)
# Poisson convergió en 4 iteraciones (Residuo: 0.000959)
# Poisson convergió en 4 iteraciones (Residuo: 0.000750)
# Poisson convergió en 3 iteraciones (Residuo: 0.000963)
# Poisson convergió en 4 iteraciones (Residuo: 0.000893)
# Poisson convergió en 4 iteraciones (Residuo: 0.000948)
# Poisson convergió en 5 iteraciones (Residuo: 0.000545)
# Poisson convergió en 1 iteraciones (Residuo: 0.000981)
# Poisson convergió en 3 iteraciones (Residuo: 0.000542)
# Poisson convergió en 3 iteraciones (Residuo: 0.000795)
# Poisson convergió en 3 iteraciones (Residuo: 0.000881)
# Poisson convergió en 2 iteraciones (Residuo: 0.000792)
# Poisson convergió en 2 iteraciones (Residuo: 0.000713)
# Poisson convergió en 3 iteraciones (Residuo: 0.000566)
# Paso de tiempo 400/10000 completado.
# Poisson convergió en 3 iteraciones (Residuo: 0.000630)
# Poisson convergió en 3 iteraciones (Residuo: 0.000861)
# Poisson convergió en 2 iteraciones (Residuo: 0.000975)
# Poisson convergió en 2 iteraciones (Residuo: 0.000955)
# Poisson convergió en 3 iteraciones (Residuo: 0.000918)
# Poisson convergió en 4 iteraciones (Residuo: 0.000683)
# Poisson convergió en 4 iteraciones (Residuo: 0.000746)
# Poisson convergió en 4 iteraciones (Residuo: 0.000629)
# Poisson convergió en 2 iteraciones (Residuo: 0.000941)
# Poisson convergió en 2 iteraciones (Residuo: 0.000938)
# Poisson convergió en 3 iteraciones (Residuo: 0.000897)
# Poisson convergió en 4 iteraciones (Residuo: 0.000764)
# Poisson convergió en 3 iteraciones (Residuo: 0.000787)
# Poisson convergió en 4 iteraciones (Residuo: 0.000905)
# Poisson convergió en 4 iteraciones (Residuo: 0.000908)
# Poisson convergió en 4 iteraciones (Residuo: 0.000963)
# Poisson convergió en 5 iteraciones (Residuo: 0.000991)
# Poisson convergió en 5 iteraciones (Residuo: 0.000876)
# Poisson convergió en 4 iteraciones (Residuo: 0.000996)
# Poisson convergió en 4 iteraciones (Residuo: 0.000996)
# Poisson convergió en 5 iteraciones (Residuo: 0.000945)
# Poisson convergió en 4 iteraciones (Residuo: 0.000826)
# Poisson convergió en 3 iteraciones (Residuo: 0.000701)
# Poisson convergió en 3 iteraciones (Residuo: 0.000608)
# Poisson convergió en 3 iteraciones (Residuo: 0.000559)
# Poisson convergió en 3 iteraciones (Residuo: 0.000537)
# Poisson convergió en 1 iteraciones (Residuo: 0.000884)
# Poisson convergió en 2 iteraciones (Residuo: 0.000576)
# Poisson convergió en 3 iteraciones (Residuo: 0.000454)
# Poisson convergió en 3 iteraciones (Residuo: 0.000424)
# Poisson convergió en 1 iteraciones (Residuo: 0.000811)
# Poisson convergió en 2 iteraciones (Residuo: 0.000417)
# Poisson convergió en 2 iteraciones (Residuo: 0.000834)
# Poisson convergió en 1 iteraciones (Residuo: 0.000947)
# Poisson convergió en 2 iteraciones (Residuo: 0.000743)
# Poisson convergió en 3 iteraciones (Residuo: 0.000474)
# Poisson convergió en 2 iteraciones (Residuo: 0.000986)
# Poisson convergió en 3 iteraciones (Residuo: 0.000941)
# Poisson convergió en 4 iteraciones (Residuo: 0.000914)
# Poisson convergió en 3 iteraciones (Residuo: 0.000976)
# Poisson convergió en 3 iteraciones (Residuo: 0.000799)
# Poisson convergió en 3 iteraciones (Residuo: 0.000767)
# Poisson convergió en 4 iteraciones (Residuo: 0.000789)
# Poisson convergió en 3 iteraciones (Residuo: 0.000856)
# Poisson convergió en 2 iteraciones (Residuo: 0.000933)
# Poisson convergió en 4 iteraciones (Residuo: 0.000992)
# Poisson convergió en 5 iteraciones (Residuo: 0.000886)
# Poisson convergió en 3 iteraciones (Residuo: 0.000889)
# Poisson convergió en 5 iteraciones (Residuo: 0.000980)
# Poisson convergió en 4 iteraciones (Residuo: 0.000852)
# Paso de tiempo 450/10000 completado.
# Poisson convergió en 5 iteraciones (Residuo: 0.000848)
# Poisson convergió en 3 iteraciones (Residuo: 0.000812)
# Poisson convergió en 3 iteraciones (Residuo: 0.000875)
# Poisson convergió en 4 iteraciones (Residuo: 0.000952)
# Poisson convergió en 5 iteraciones (Residuo: 0.000803)
# Poisson convergió en 4 iteraciones (Residuo: 0.000925)
# Poisson convergió en 5 iteraciones (Residuo: 0.000517)
# Poisson convergió en 2 iteraciones (Residuo: 0.000987)
# Poisson convergió en 2 iteraciones (Residuo: 0.000985)
# Poisson convergió en 4 iteraciones (Residuo: 0.000442)
# Poisson convergió en 1 iteraciones (Residuo: 0.000994)
# Poisson convergió en 3 iteraciones (Residuo: 0.000708)
# Poisson convergió en 3 iteraciones (Residuo: 0.000928)
# Poisson convergió en 1 iteraciones (Residuo: 0.000947)
# Poisson convergió en 3 iteraciones (Residuo: 0.000636)
# Poisson convergió en 3 iteraciones (Residuo: 0.000999)
# Poisson convergió en 2 iteraciones (Residuo: 0.000765)
# Poisson convergió en 3 iteraciones (Residuo: 0.000391)
# Poisson convergió en 3 iteraciones (Residuo: 0.000619)
# Poisson convergió en 1 iteraciones (Residuo: 0.000448)
# Poisson convergió en 1 iteraciones (Residuo: 0.000826)
# Poisson convergió en 1 iteraciones (Residuo: 0.000923)
# Poisson convergió en 1 iteraciones (Residuo: 0.000828)
# Poisson convergió en 2 iteraciones (Residuo: 0.000907)
# Poisson convergió en 4 iteraciones (Residuo: 0.000848)
# Poisson convergió en 5 iteraciones (Residuo: 0.000870)
# Poisson convergió en 4 iteraciones (Residuo: 0.000925)
# Poisson convergió en 4 iteraciones (Residuo: 0.000846)
# Poisson convergió en 4 iteraciones (Residuo: 0.000868)
# Poisson convergió en 4 iteraciones (Residuo: 0.000981)
# Poisson convergió en 5 iteraciones (Residuo: 0.000910)
# Poisson convergió en 5 iteraciones (Residuo: 0.000864)
# Poisson convergió en 5 iteraciones (Residuo: 0.000827)
# Poisson convergió en 4 iteraciones (Residuo: 0.000933)
# Poisson convergió en 5 iteraciones (Residuo: 0.000813)
# Poisson convergió en 4 iteraciones (Residuo: 0.000979)
# Poisson convergió en 5 iteraciones (Residuo: 0.000559)
# Poisson convergió en 4 iteraciones (Residuo: 0.000612)
# Poisson convergió en 4 iteraciones (Residuo: 0.000606)
# Poisson convergió en 2 iteraciones (Residuo: 0.000952)
# Poisson convergió en 2 iteraciones (Residuo: 0.000856)
# Poisson convergió en 3 iteraciones (Residuo: 0.000827)
# Poisson convergió en 2 iteraciones (Residuo: 0.000966)
# Poisson convergió en 2 iteraciones (Residuo: 0.000785)
# Poisson convergió en 3 iteraciones (Residuo: 0.000803)
# Poisson convergió en 3 iteraciones (Residuo: 0.000862)
# Poisson convergió en 1 iteraciones (Residuo: 0.000760)
# Poisson convergió en 2 iteraciones (Residuo: 0.000984)
# Poisson convergió en 2 iteraciones (Residuo: 0.000489)
# Poisson convergió en 2 iteraciones (Residuo: 0.000914)
# Paso de tiempo 500/10000 completado.
# Poisson convergió en 1 iteraciones (Residuo: 0.000440)
# Poisson convergió en 1 iteraciones (Residuo: 0.000738)
# Poisson convergió en 2 iteraciones (Residuo: 0.000691)
# Poisson convergió en 1 iteraciones (Residuo: 0.000959)
# Poisson convergió en 3 iteraciones (Residuo: 0.000479)
# Poisson convergió en 3 iteraciones (Residuo: 0.000724)
# Poisson convergió en 1 iteraciones (Residuo: 0.000964)
# Poisson convergió en 3 iteraciones (Residuo: 0.000647)
# Poisson convergió en 3 iteraciones (Residuo: 0.000910)
# Poisson convergió en 5 iteraciones (Residuo: 0.000934)
# Poisson convergió en 5 iteraciones (Residuo: 0.000906)
# Poisson convergió en 5 iteraciones (Residuo: 0.000995)
# Poisson convergió en 6 iteraciones (Residuo: 0.000902)
# Poisson convergió en 5 iteraciones (Residuo: 0.000808)
# Poisson convergió en 5 iteraciones (Residuo: 0.000791)
# Poisson convergió en 4 iteraciones (Residuo: 0.000920)
# Poisson convergió en 4 iteraciones (Residuo: 0.000897)
# Poisson convergió en 4 iteraciones (Residuo: 0.000960)
# Poisson convergió en 5 iteraciones (Residuo: 0.000744)
# Poisson convergió en 4 iteraciones (Residuo: 0.000607)
# Poisson convergió en 4 iteraciones (Residuo: 0.000515)
# Poisson convergió en 2 iteraciones (Residuo: 0.000911)
# Poisson convergió en 2 iteraciones (Residuo: 0.000672)
# Poisson convergió en 3 iteraciones (Residuo: 0.000738)
# Poisson convergió en 1 iteraciones (Residuo: 0.000971)
# Poisson convergió en 3 iteraciones (Residuo: 0.000719)
# Poisson convergió en 3 iteraciones (Residuo: 0.000930)
# Poisson convergió en 2 iteraciones (Residuo: 0.000617)
# Poisson convergió en 3 iteraciones (Residuo: 0.000702)
# Poisson convergió en 2 iteraciones (Residuo: 0.000864)
# Poisson convergió en 2 iteraciones (Residuo: 0.000901)
# Poisson convergió en 3 iteraciones (Residuo: 0.000817)
# Poisson convergió en 1 iteraciones (Residuo: 0.000982)
# Poisson convergió en 3 iteraciones (Residuo: 0.000579)
# Poisson convergió en 3 iteraciones (Residuo: 0.000713)
# Poisson convergió en 1 iteraciones (Residuo: 0.000821)
# Poisson convergió en 2 iteraciones (Residuo: 0.000878)
# Poisson convergió en 1 iteraciones (Residuo: 0.000969)
# Poisson convergió en 2 iteraciones (Residuo: 0.000798)
# Poisson convergió en 2 iteraciones (Residuo: 0.000824)
# Poisson convergió en 3 iteraciones (Residuo: 0.000906)
# Poisson convergió en 4 iteraciones (Residuo: 0.000930)
# Poisson convergió en 4 iteraciones (Residuo: 0.000958)
# Poisson convergió en 6 iteraciones (Residuo: 0.000858)
# Poisson convergió en 4 iteraciones (Residuo: 0.000906)
# Poisson convergió en 5 iteraciones (Residuo: 0.000972)
# Poisson convergió en 6 iteraciones (Residuo: 0.000849)
# Poisson convergió en 4 iteraciones (Residuo: 0.000893)
# Poisson convergió en 4 iteraciones (Residuo: 0.000966)
# Poisson convergió en 5 iteraciones (Residuo: 0.000853)
# Paso de tiempo 550/10000 completado.
# Poisson convergió en 4 iteraciones (Residuo: 0.000861)
# Poisson convergió en 4 iteraciones (Residuo: 0.000749)
# Poisson convergió en 4 iteraciones (Residuo: 0.000673)
# Poisson convergió en 3 iteraciones (Residuo: 0.000908)
# Poisson convergió en 4 iteraciones (Residuo: 0.000491)
# Poisson convergió en 3 iteraciones (Residuo: 0.000808)
# Poisson convergió en 1 iteraciones (Residuo: 0.000905)
# Poisson convergió en 3 iteraciones (Residuo: 0.000518)
# Poisson convergió en 3 iteraciones (Residuo: 0.000722)
# Poisson convergió en 2 iteraciones (Residuo: 0.000946)
# Poisson convergió en 2 iteraciones (Residuo: 0.000701)
# Poisson convergió en 3 iteraciones (Residuo: 0.000523)
# Poisson convergió en 3 iteraciones (Residuo: 0.000527)
# Poisson convergió en 3 iteraciones (Residuo: 0.000569)
# Poisson convergió en 1 iteraciones (Residuo: 0.000955)
# Poisson convergió en 3 iteraciones (Residuo: 0.000349)
# Poisson convergió en 3 iteraciones (Residuo: 0.000484)
# Poisson convergió en 1 iteraciones (Residuo: 0.000670)
# Poisson convergió en 2 iteraciones (Residuo: 0.000666)
# Poisson convergió en 1 iteraciones (Residuo: 0.000619)
# Poisson convergió en 2 iteraciones (Residuo: 0.000667)
# Poisson convergió en 2 iteraciones (Residuo: 0.000990)
# Poisson convergió en 4 iteraciones (Residuo: 0.000949)
# Poisson convergió en 4 iteraciones (Residuo: 0.000905)
# Poisson convergió en 4 iteraciones (Residuo: 0.000928)
# Poisson convergió en 4 iteraciones (Residuo: 0.000952)
# Poisson convergió en 4 iteraciones (Residuo: 0.000993)
# Poisson convergió en 4 iteraciones (Residuo: 0.000929)
# Poisson convergió en 4 iteraciones (Residuo: 0.000776)
# Poisson convergió en 4 iteraciones (Residuo: 0.000914)
# Poisson convergió en 5 iteraciones (Residuo: 0.000929)
# Poisson convergió en 6 iteraciones (Residuo: 0.000812)
# Poisson convergió en 3 iteraciones (Residuo: 0.000999)
# Poisson convergió en 3 iteraciones (Residuo: 0.000958)
# Poisson convergió en 4 iteraciones (Residuo: 0.000831)
# Poisson convergió en 4 iteraciones (Residuo: 0.000659)
# Poisson convergió en 4 iteraciones (Residuo: 0.000545)
# Poisson convergió en 3 iteraciones (Residuo: 0.000968)
# Poisson convergió en 2 iteraciones (Residuo: 0.000920)
# Poisson convergió en 2 iteraciones (Residuo: 0.000963)
# Poisson convergió en 3 iteraciones (Residuo: 0.000943)
# Poisson convergió en 4 iteraciones (Residuo: 0.000485)
# Poisson convergió en 1 iteraciones (Residuo: 0.000992)
# Poisson convergió en 3 iteraciones (Residuo: 0.000600)
# Poisson convergió en 3 iteraciones (Residuo: 0.000811)
# Poisson convergió en 4 iteraciones (Residuo: 0.000445)
# Poisson convergió en 2 iteraciones (Residuo: 0.000998)
# Poisson convergió en 2 iteraciones (Residuo: 0.000584)
# Poisson convergió en 3 iteraciones (Residuo: 0.000478)
# Poisson convergió en 3 iteraciones (Residuo: 0.000622)
# Paso de tiempo 600/10000 completado.
# Poisson convergió en 1 iteraciones (Residuo: 0.000682)
# Poisson convergió en 2 iteraciones (Residuo: 0.000720)
# Poisson convergió en 1 iteraciones (Residuo: 0.000808)
# Poisson convergió en 2 iteraciones (Residuo: 0.000712)
# Poisson convergió en 1 iteraciones (Residuo: 0.000859)
# Poisson convergió en 2 iteraciones (Residuo: 0.000943)
# Poisson convergió en 5 iteraciones (Residuo: 0.000853)
# Poisson convergió en 3 iteraciones (Residuo: 0.000975)
# Poisson convergió en 5 iteraciones (Residuo: 0.000882)
# Poisson convergió en 5 iteraciones (Residuo: 0.000732)
# Poisson convergió en 4 iteraciones (Residuo: 0.000783)
# Poisson convergió en 4 iteraciones (Residuo: 0.000737)
# Poisson convergió en 4 iteraciones (Residuo: 0.000519)
# Poisson convergió en 1 iteraciones (Residuo: 0.000825)
# Poisson convergió en 2 iteraciones (Residuo: 0.000843)
# Poisson convergió en 1 iteraciones (Residuo: 0.000915)
# Poisson convergió en 2 iteraciones (Residuo: 0.000806)
# Poisson convergió en 3 iteraciones (Residuo: 0.000833)
# Poisson convergió en 4 iteraciones (Residuo: 0.000983)
# Poisson convergió en 5 iteraciones (Residuo: 0.000968)
# Poisson convergió en 4 iteraciones (Residuo: 0.000984)
# Poisson convergió en 5 iteraciones (Residuo: 0.000799)
# Poisson convergió en 4 iteraciones (Residuo: 0.000875)
# Poisson convergió en 4 iteraciones (Residuo: 0.000827)
# Poisson convergió en 2 iteraciones (Residuo: 0.000881)
# Poisson convergió en 2 iteraciones (Residuo: 0.000972)
# Poisson convergió en 3 iteraciones (Residuo: 0.000760)
# Poisson convergió en 4 iteraciones (Residuo: 0.000639)
# Poisson convergió en 3 iteraciones (Residuo: 0.000879)
# Poisson convergió en 2 iteraciones (Residuo: 0.000942)
# Poisson convergió en 2 iteraciones (Residuo: 0.000795)
# Poisson convergió en 4 iteraciones (Residuo: 0.000457)
# Poisson convergió en 4 iteraciones (Residuo: 0.000623)
# Poisson convergió en 1 iteraciones (Residuo: 0.000858)
# Poisson convergió en 3 iteraciones (Residuo: 0.000616)
# Poisson convergió en 3 iteraciones (Residuo: 0.000892)
# Poisson convergió en 2 iteraciones (Residuo: 0.000987)
# Poisson convergió en 2 iteraciones (Residuo: 0.000879)
# Poisson convergió en 3 iteraciones (Residuo: 0.000786)
# Poisson convergió en 2 iteraciones (Residuo: 0.000993)
# Poisson convergió en 4 iteraciones (Residuo: 0.000957)
# Poisson convergió en 5 iteraciones (Residuo: 0.000867)
# Poisson convergió en 4 iteraciones (Residuo: 0.000807)
# Poisson convergió en 3 iteraciones (Residuo: 0.000799)
# Poisson convergió en 3 iteraciones (Residuo: 0.000757)
# Poisson convergió en 3 iteraciones (Residuo: 0.000875)
# Poisson convergió en 2 iteraciones (Residuo: 0.000933)
# Poisson convergió en 2 iteraciones (Residuo: 0.000818)
# Poisson convergió en 4 iteraciones (Residuo: 0.000789)
# Poisson convergió en 4 iteraciones (Residuo: 0.000897)
# Paso de tiempo 650/10000 completado.
# Poisson convergió en 5 iteraciones (Residuo: 0.000629)
# Poisson convergió en 4 iteraciones (Residuo: 0.000640)
# Poisson convergió en 4 iteraciones (Residuo: 0.000656)
# Poisson convergió en 4 iteraciones (Residuo: 0.000547)
# Poisson convergió en 3 iteraciones (Residuo: 0.000867)
# Poisson convergió en 2 iteraciones (Residuo: 0.000887)
# Poisson convergió en 2 iteraciones (Residuo: 0.000789)
# Poisson convergió en 3 iteraciones (Residuo: 0.000826)
# Poisson convergió en 1 iteraciones (Residuo: 0.000855)
# Poisson convergió en 3 iteraciones (Residuo: 0.000616)
# Poisson convergió en 3 iteraciones (Residuo: 0.000957)
# Poisson convergió en 5 iteraciones (Residuo: 0.000882)
# Poisson convergió en 4 iteraciones (Residuo: 0.000827)
# Poisson convergió en 4 iteraciones (Residuo: 0.000693)
# Poisson convergió en 4 iteraciones (Residuo: 0.000499)
# Poisson convergió en 3 iteraciones (Residuo: 0.000738)
# Poisson convergió en 1 iteraciones (Residuo: 0.000913)
# Poisson convergió en 3 iteraciones (Residuo: 0.000457)
# Poisson convergió en 3 iteraciones (Residuo: 0.000736)
# Poisson convergió en 1 iteraciones (Residuo: 0.000807)
# Poisson convergió en 3 iteraciones (Residuo: 0.000527)
# Poisson convergió en 3 iteraciones (Residuo: 0.000859)
# Poisson convergió en 1 iteraciones (Residuo: 0.000947)
# Poisson convergió en 3 iteraciones (Residuo: 0.000901)
# Poisson convergió en 3 iteraciones (Residuo: 0.000994)
# Poisson convergió en 4 iteraciones (Residuo: 0.000940)
# Poisson convergió en 4 iteraciones (Residuo: 0.000944)
# Poisson convergió en 4 iteraciones (Residuo: 0.000872)
# Poisson convergió en 4 iteraciones (Residuo: 0.000794)
# Poisson convergió en 3 iteraciones (Residuo: 0.000732)
# Poisson convergió en 3 iteraciones (Residuo: 0.000791)
# Poisson convergió en 3 iteraciones (Residuo: 0.000814)
# Poisson convergió en 3 iteraciones (Residuo: 0.000958)
# Poisson convergió en 4 iteraciones (Residuo: 0.000857)
# Poisson convergió en 5 iteraciones (Residuo: 0.000839)
# Poisson convergió en 4 iteraciones (Residuo: 0.000811)
# Poisson convergió en 4 iteraciones (Residuo: 0.000586)
# Poisson convergió en 2 iteraciones (Residuo: 0.000848)
# Poisson convergió en 2 iteraciones (Residuo: 0.000654)
# Poisson convergió en 3 iteraciones (Residuo: 0.000490)
# Poisson convergió en 2 iteraciones (Residuo: 0.000991)
# Poisson convergió en 3 iteraciones (Residuo: 0.000902)
# Poisson convergió en 5 iteraciones (Residuo: 0.000836)
# Poisson convergió en 5 iteraciones (Residuo: 0.000741)
# Poisson convergió en 4 iteraciones (Residuo: 0.000968)
# Poisson convergió en 4 iteraciones (Residuo: 0.000934)
# Poisson convergió en 4 iteraciones (Residuo: 0.000836)
# Poisson convergió en 4 iteraciones (Residuo: 0.000606)
# Poisson convergió en 1 iteraciones (Residuo: 0.000955)
# Poisson convergió en 3 iteraciones (Residuo: 0.000579)
# Paso de tiempo 700/10000 completado.
# Poisson convergió en 3 iteraciones (Residuo: 0.000851)
# Poisson convergió en 1 iteraciones (Residuo: 0.000823)
# Poisson convergió en 3 iteraciones (Residuo: 0.000408)
# Poisson convergió en 3 iteraciones (Residuo: 0.000641)
# Poisson convergió en 1 iteraciones (Residuo: 0.000576)
# Poisson convergió en 2 iteraciones (Residuo: 0.000756)
# Poisson convergió en 1 iteraciones (Residuo: 0.000513)
# Poisson convergió en 2 iteraciones (Residuo: 0.000770)
# Poisson convergió en 1 iteraciones (Residuo: 0.000510)
# Poisson convergió en 1 iteraciones (Residuo: 0.000822)
# Poisson convergió en 2 iteraciones (Residuo: 0.000724)
# Poisson convergió en 3 iteraciones (Residuo: 0.000942)
# Poisson convergió en 4 iteraciones (Residuo: 0.000992)
# Poisson convergió en 5 iteraciones (Residuo: 0.000999)
# Poisson convergió en 6 iteraciones (Residuo: 0.000799)
# Poisson convergió en 4 iteraciones (Residuo: 0.000933)
# Poisson convergió en 5 iteraciones (Residuo: 0.000642)
# Poisson convergió en 4 iteraciones (Residuo: 0.000774)
# Poisson convergió en 4 iteraciones (Residuo: 0.000644)
# Poisson convergió en 2 iteraciones (Residuo: 0.000911)
# Poisson convergió en 2 iteraciones (Residuo: 0.000927)
# Poisson convergió en 4 iteraciones (Residuo: 0.000378)
# Poisson convergió en 2 iteraciones (Residuo: 0.000941)
# Poisson convergió en 2 iteraciones (Residuo: 0.000713)
# Poisson convergió en 3 iteraciones (Residuo: 0.000928)
# Poisson convergió en 5 iteraciones (Residuo: 0.000944)
# Poisson convergió en 5 iteraciones (Residuo: 0.000897)
# Poisson convergió en 4 iteraciones (Residuo: 0.000960)
# Poisson convergió en 4 iteraciones (Residuo: 0.000981)
# Poisson convergió en 4 iteraciones (Residuo: 0.000893)
# Poisson convergió en 4 iteraciones (Residuo: 0.000798)
# Poisson convergió en 4 iteraciones (Residuo: 0.000637)
# Poisson convergió en 2 iteraciones (Residuo: 0.000975)
# Poisson convergió en 2 iteraciones (Residuo: 0.000700)
# Poisson convergió en 3 iteraciones (Residuo: 0.000692)
# Poisson convergió en 1 iteraciones (Residuo: 0.000967)
# Poisson convergió en 3 iteraciones (Residuo: 0.000428)
# Poisson convergió en 3 iteraciones (Residuo: 0.000571)
# Poisson convergió en 1 iteraciones (Residuo: 0.000588)
# Poisson convergió en 2 iteraciones (Residuo: 0.000656)
# Poisson convergió en 1 iteraciones (Residuo: 0.000685)
# Poisson convergió en 2 iteraciones (Residuo: 0.000747)
# Poisson convergió en 2 iteraciones (Residuo: 0.000969)
# Poisson convergió en 3 iteraciones (Residuo: 0.000930)
# Poisson convergió en 5 iteraciones (Residuo: 0.000800)
# Poisson convergió en 5 iteraciones (Residuo: 0.000708)
# Poisson convergió en 4 iteraciones (Residuo: 0.000977)
# Poisson convergió en 5 iteraciones (Residuo: 0.000647)
# Poisson convergió en 4 iteraciones (Residuo: 0.000873)
# Poisson convergió en 2 iteraciones (Residuo: 0.000939)
# Paso de tiempo 750/10000 completado.
# Poisson convergió en 3 iteraciones (Residuo: 0.000693)
# Poisson convergió en 4 iteraciones (Residuo: 0.000461)
# Poisson convergió en 3 iteraciones (Residuo: 0.000786)
# Poisson convergió en 1 iteraciones (Residuo: 0.000790)
# Poisson convergió en 3 iteraciones (Residuo: 0.000544)
# Poisson convergió en 3 iteraciones (Residuo: 0.000802)
# Poisson convergió en 1 iteraciones (Residuo: 0.000774)
# Poisson convergió en 1 iteraciones (Residuo: 0.000847)
# Poisson convergió en 2 iteraciones (Residuo: 0.000979)
# Poisson convergió en 5 iteraciones (Residuo: 0.000949)
# Poisson convergió en 5 iteraciones (Residuo: 0.000903)
# Poisson convergió en 5 iteraciones (Residuo: 0.000949)
# Poisson convergió en 5 iteraciones (Residuo: 0.000989)
# Poisson convergió en 5 iteraciones (Residuo: 0.000764)
# Poisson convergió en 3 iteraciones (Residuo: 0.000979)
# Poisson convergió en 2 iteraciones (Residuo: 0.000952)
# Poisson convergió en 3 iteraciones (Residuo: 0.000792)
# Poisson convergió en 4 iteraciones (Residuo: 0.000468)
# Poisson convergió en 3 iteraciones (Residuo: 0.000750)
# Poisson convergió en 1 iteraciones (Residuo: 0.000683)
# Poisson convergió en 2 iteraciones (Residuo: 0.000893)
# Poisson convergió en 1 iteraciones (Residuo: 0.000999)
# Poisson convergió en 3 iteraciones (Residuo: 0.000425)
# Poisson convergió en 3 iteraciones (Residuo: 0.000606)
# Poisson convergió en 1 iteraciones (Residuo: 0.000758)
# Poisson convergió en 3 iteraciones (Residuo: 0.000515)
# Poisson convergió en 3 iteraciones (Residuo: 0.000552)
# Poisson convergió en 2 iteraciones (Residuo: 0.000734)
# Poisson convergió en 2 iteraciones (Residuo: 0.000873)
# Poisson convergió en 4 iteraciones (Residuo: 0.000889)
# Poisson convergió en 5 iteraciones (Residuo: 0.000809)
# Poisson convergió en 3 iteraciones (Residuo: 0.000884)
# Poisson convergió en 2 iteraciones (Residuo: 0.000916)
# Poisson convergió en 4 iteraciones (Residuo: 0.000900)
# Poisson convergió en 5 iteraciones (Residuo: 0.000972)
# Poisson convergió en 5 iteraciones (Residuo: 0.000673)
# Poisson convergió en 2 iteraciones (Residuo: 0.000942)
# Poisson convergió en 3 iteraciones (Residuo: 0.000432)
# Poisson convergió en 3 iteraciones (Residuo: 0.000751)
# Poisson convergió en 1 iteraciones (Residuo: 0.000551)
# Poisson convergió en 1 iteraciones (Residuo: 0.000951)
# Poisson convergió en 2 iteraciones (Residuo: 0.000548)
# Poisson convergió en 2 iteraciones (Residuo: 0.000840)
# Poisson convergió en 3 iteraciones (Residuo: 0.000888)
# Poisson convergió en 4 iteraciones (Residuo: 0.000798)
# Poisson convergió en 3 iteraciones (Residuo: 0.000918)
# Poisson convergió en 3 iteraciones (Residuo: 0.000981)
# Poisson convergió en 4 iteraciones (Residuo: 0.000797)
# Poisson convergió en 3 iteraciones (Residuo: 0.000775)
# Poisson convergió en 4 iteraciones (Residuo: 0.000440)
# Paso de tiempo 800/10000 completado.
# Poisson convergió en 2 iteraciones (Residuo: 0.000940)
# Poisson convergió en 3 iteraciones (Residuo: 0.000753)
# Poisson convergió en 4 iteraciones (Residuo: 0.000827)
# Poisson convergió en 4 iteraciones (Residuo: 0.000940)
# Poisson convergió en 3 iteraciones (Residuo: 0.000936)
# Poisson convergió en 3 iteraciones (Residuo: 0.000911)
# Poisson convergió en 4 iteraciones (Residuo: 0.000619)
# Poisson convergió en 3 iteraciones (Residuo: 0.000775)
# Poisson convergió en 3 iteraciones (Residuo: 0.000871)
# Poisson convergió en 2 iteraciones (Residuo: 0.000924)
# Poisson convergió en 2 iteraciones (Residuo: 0.000857)
# Poisson convergió en 3 iteraciones (Residuo: 0.000981)
# Poisson convergió en 5 iteraciones (Residuo: 0.000969)
# Poisson convergió en 5 iteraciones (Residuo: 0.000837)
# Poisson convergió en 4 iteraciones (Residuo: 0.000888)
# Poisson convergió en 4 iteraciones (Residuo: 0.000862)
# Poisson convergió en 4 iteraciones (Residuo: 0.000851)
# Poisson convergió en 4 iteraciones (Residuo: 0.000734)
# Poisson convergió en 2 iteraciones (Residuo: 0.000990)
# Poisson convergió en 2 iteraciones (Residuo: 0.000858)
# Poisson convergió en 3 iteraciones (Residuo: 0.000913)
# Poisson convergió en 3 iteraciones (Residuo: 0.000988)
# Poisson convergió en 2 iteraciones (Residuo: 0.000725)
# Poisson convergió en 3 iteraciones (Residuo: 0.000458)
# Poisson convergió en 3 iteraciones (Residuo: 0.000755)
# Poisson convergió en 1 iteraciones (Residuo: 0.000803)
# Poisson convergió en 3 iteraciones (Residuo: 0.000690)
# Poisson convergió en 2 iteraciones (Residuo: 0.000907)
# Poisson convergió en 3 iteraciones (Residuo: 0.000793)
# Poisson convergió en 3 iteraciones (Residuo: 0.000955)
# Poisson convergió en 4 iteraciones (Residuo: 0.000713)
# Poisson convergió en 4 iteraciones (Residuo: 0.000582)
# Poisson convergió en 3 iteraciones (Residuo: 0.000770)
# Poisson convergió en 2 iteraciones (Residuo: 0.000992)
# Poisson convergió en 2 iteraciones (Residuo: 0.000901)
# Poisson convergió en 3 iteraciones (Residuo: 0.000820)
# Poisson convergió en 4 iteraciones (Residuo: 0.000653)
# Poisson convergió en 4 iteraciones (Residuo: 0.000722)
# Poisson convergió en 4 iteraciones (Residuo: 0.000645)
# Poisson convergió en 2 iteraciones (Residuo: 0.000829)
# Poisson convergió en 2 iteraciones (Residuo: 0.000713)
# Poisson convergió en 3 iteraciones (Residuo: 0.000597)
# Poisson convergió en 2 iteraciones (Residuo: 0.000934)
# Poisson convergió en 4 iteraciones (Residuo: 0.000872)
# Poisson convergió en 5 iteraciones (Residuo: 0.000941)
# Poisson convergió en 5 iteraciones (Residuo: 0.000875)
# Poisson convergió en 5 iteraciones (Residuo: 0.000669)
# Poisson convergió en 3 iteraciones (Residuo: 0.000985)
# Poisson convergió en 2 iteraciones (Residuo: 0.000959)
# Poisson convergió en 4 iteraciones (Residuo: 0.000457)
# Paso de tiempo 850/10000 completado.
# Poisson convergió en 4 iteraciones (Residuo: 0.000474)
# Poisson convergió en 1 iteraciones (Residuo: 0.000733)
# Poisson convergió en 3 iteraciones (Residuo: 0.000621)
# Poisson convergió en 2 iteraciones (Residuo: 0.000887)
# Poisson convergió en 3 iteraciones (Residuo: 0.000728)
# Poisson convergió en 3 iteraciones (Residuo: 0.000851)
# Poisson convergió en 4 iteraciones (Residuo: 0.000485)
# Poisson convergió en 3 iteraciones (Residuo: 0.000807)
# ...
# Poisson convergió en 2 iteraciones (Residuo: 0.000906)
# Poisson convergió en 3 iteraciones (Residuo: 0.000621)
# Poisson convergió en 2 iteraciones (Residuo: 0.000981)
# Poisson convergió en 3 iteraciones (Residuo: 0.000563)
# Poisson convergió en 2 iteraciones (Residuo: 0.000968)
# Poisson convergió en 3 iteraciones (Residuo: 0.000788)
# Poisson convergió en 3 iteraciones (Residuo: 0.000841)
# Poisson convergió en 3 iteraciones (Residuo: 0.000795)
# Poisson convergió en 3 iteraciones (Residuo: 0.000762)
# Poisson convergió en 3 iteraciones (Residuo: 0.000729)
# Poisson convergió en 3 iteraciones (Residuo: 0.000691)
# Poisson convergió en 3 iteraciones (Residuo: 0.000631)
# Poisson convergió en 3 iteraciones (Residuo: 0.000611)
# Poisson convergió en 2 iteraciones (Residuo: 0.000913)
# Poisson convergió en 2 iteraciones (Residuo: 0.000964)
# Poisson convergió en 3 iteraciones (Residuo: 0.000704)
# Poisson convergió en 2 iteraciones (Residuo: 0.000942)
# Poisson convergió en 2 iteraciones (Residuo: 0.000879)
# Poisson convergió en 2 iteraciones (Residuo: 0.000884)
# Poisson convergió en 3 iteraciones (Residuo: 0.000785)
# Poisson convergió en 3 iteraciones (Residuo: 0.000745)
# Poisson convergió en 3 iteraciones (Residuo: 0.000659)
# Poisson convergió en 2 iteraciones (Residuo: 0.000852)
# Poisson convergió en 3 iteraciones (Residuo: 0.000547)
# Poisson convergió en 2 iteraciones (Residuo: 0.000870)
# Poisson convergió en 2 iteraciones (Residuo: 0.000796)
# Poisson convergió en 2 iteraciones (Residuo: 0.000939)
# Poisson convergió en 2 iteraciones (Residuo: 0.000899)
# Poisson convergió en 2 iteraciones (Residuo: 0.000952)
# Poisson convergió en 3 iteraciones (Residuo: 0.000798)
# Poisson convergió en 3 iteraciones (Residuo: 0.000820)
# Poisson convergió en 3 iteraciones (Residuo: 0.000855)
# Poisson convergió en 3 iteraciones (Residuo: 0.000865)
# Poisson convergió en 3 iteraciones (Residuo: 0.000845)
# Poisson convergió en 3 iteraciones (Residuo: 0.000862)
# Poisson convergió en 3 iteraciones (Residuo: 0.000896)
# Poisson convergió en 3 iteraciones (Residuo: 0.000878)
# Poisson convergió en 3 iteraciones (Residuo: 0.000810)
# Paso de tiempo 9750/10000 completado.
# Poisson convergió en 2 iteraciones (Residuo: 0.000992)
# Poisson convergió en 2 iteraciones (Residuo: 0.000897)
# Poisson convergió en 3 iteraciones (Residuo: 0.000796)
# Poisson convergió en 3 iteraciones (Residuo: 0.000698)
# Poisson convergió en 2 iteraciones (Residuo: 0.000897)
# Poisson convergió en 3 iteraciones (Residuo: 0.000563)
# Poisson convergió en 2 iteraciones (Residuo: 0.000940)
# Poisson convergió en 2 iteraciones (Residuo: 0.000988)
# Poisson convergió en 3 iteraciones (Residuo: 0.000741)
# Poisson convergió en 2 iteraciones (Residuo: 0.000974)
# Poisson convergió en 2 iteraciones (Residuo: 0.000963)
# Poisson convergió en 3 iteraciones (Residuo: 0.000845)
# Poisson convergió en 3 iteraciones (Residuo: 0.000821)
# Poisson convergió en 2 iteraciones (Residuo: 0.000996)
# Poisson convergió en 3 iteraciones (Residuo: 0.000717)
# Poisson convergió en 3 iteraciones (Residuo: 0.000632)
# Poisson convergió en 2 iteraciones (Residuo: 0.000775)
# Poisson convergió en 2 iteraciones (Residuo: 0.000979)
# Poisson convergió en 3 iteraciones (Residuo: 0.000627)
# Poisson convergió en 2 iteraciones (Residuo: 0.000887)
# Poisson convergió en 2 iteraciones (Residuo: 0.000978)
# Poisson convergió en 3 iteraciones (Residuo: 0.000809)
# Poisson convergió en 3 iteraciones (Residuo: 0.000759)
# Poisson convergió en 3 iteraciones (Residuo: 0.000747)
# Poisson convergió en 3 iteraciones (Residuo: 0.000732)
# Poisson convergió en 3 iteraciones (Residuo: 0.000697)
# Poisson convergió en 3 iteraciones (Residuo: 0.000635)
# Poisson convergió en 2 iteraciones (Residuo: 0.000932)
# Poisson convergió en 2 iteraciones (Residuo: 0.000912)
# Poisson convergió en 3 iteraciones (Residuo: 0.000831)
# Poisson convergió en 2 iteraciones (Residuo: 0.000931)
# Poisson convergió en 2 iteraciones (Residuo: 0.000963)
# Poisson convergió en 3 iteraciones (Residuo: 0.000721)
# Poisson convergió en 3 iteraciones (Residuo: 0.000623)
# Poisson convergió en 2 iteraciones (Residuo: 0.000969)
# Poisson convergió en 3 iteraciones (Residuo: 0.000558)
# Poisson convergió en 2 iteraciones (Residuo: 0.000955)
# Poisson convergió en 3 iteraciones (Residuo: 0.000677)
# Poisson convergió en 3 iteraciones (Residuo: 0.000687)
# Poisson convergió en 2 iteraciones (Residuo: 0.000995)
# Poisson convergió en 3 iteraciones (Residuo: 0.000710)
# Poisson convergió en 2 iteraciones (Residuo: 0.000934)
# Poisson convergió en 2 iteraciones (Residuo: 0.000732)
# Poisson convergió en 3 iteraciones (Residuo: 0.000604)
# Poisson convergió en 2 iteraciones (Residuo: 0.000806)
# Poisson convergió en 2 iteraciones (Residuo: 0.000769)
# Poisson convergió en 3 iteraciones (Residuo: 0.000596)
# Poisson convergió en 2 iteraciones (Residuo: 0.000910)
# Poisson convergió en 2 iteraciones (Residuo: 0.000930)
# Poisson convergió en 3 iteraciones (Residuo: 0.000895)
# Paso de tiempo 9800/10000 completado.
# Poisson convergió en 3 iteraciones (Residuo: 0.000855)
# Poisson convergió en 3 iteraciones (Residuo: 0.000763)
# Poisson convergió en 3 iteraciones (Residuo: 0.000770)
# Poisson convergió en 3 iteraciones (Residuo: 0.000755)
# Poisson convergió en 3 iteraciones (Residuo: 0.000690)
# Poisson convergió en 2 iteraciones (Residuo: 0.000995)
# Poisson convergió en 2 iteraciones (Residuo: 0.000963)
# Poisson convergió en 2 iteraciones (Residuo: 0.000989)
# Poisson convergió en 3 iteraciones (Residuo: 0.000883)
# Poisson convergió en 3 iteraciones (Residuo: 0.000823)
# Poisson convergió en 2 iteraciones (Residuo: 0.000961)
# Poisson convergió en 3 iteraciones (Residuo: 0.000721)
# Poisson convergió en 3 iteraciones (Residuo: 0.000709)
# Poisson convergió en 3 iteraciones (Residuo: 0.000663)
# Poisson convergió en 2 iteraciones (Residuo: 0.000994)
# Poisson convergió en 3 iteraciones (Residuo: 0.000603)
# Poisson convergió en 3 iteraciones (Residuo: 0.000559)
# Poisson convergió en 2 iteraciones (Residuo: 0.000842)
# Poisson convergió en 3 iteraciones (Residuo: 0.000660)
# Poisson convergió en 2 iteraciones (Residuo: 0.000994)
# Poisson convergió en 2 iteraciones (Residuo: 0.000924)
# Poisson convergió en 3 iteraciones (Residuo: 0.000853)
# Poisson convergió en 2 iteraciones (Residuo: 0.000990)
# Poisson convergió en 3 iteraciones (Residuo: 0.000633)
# Poisson convergió en 2 iteraciones (Residuo: 0.000850)
# Poisson convergió en 2 iteraciones (Residuo: 0.000899)
# Poisson convergió en 3 iteraciones (Residuo: 0.000561)
# Poisson convergió en 2 iteraciones (Residuo: 0.000809)
# Poisson convergió en 2 iteraciones (Residuo: 0.000938)
# Poisson convergió en 3 iteraciones (Residuo: 0.000807)
# Poisson convergió en 3 iteraciones (Residuo: 0.000835)
# Poisson convergió en 3 iteraciones (Residuo: 0.000849)
# Poisson convergió en 3 iteraciones (Residuo: 0.000792)
# Poisson convergió en 3 iteraciones (Residuo: 0.000697)
# Poisson convergió en 3 iteraciones (Residuo: 0.000586)
# Poisson convergió en 2 iteraciones (Residuo: 0.000871)
# Poisson convergió en 2 iteraciones (Residuo: 0.000980)
# Poisson convergió en 3 iteraciones (Residuo: 0.000846)
# Poisson convergió en 3 iteraciones (Residuo: 0.000781)
# Poisson convergió en 2 iteraciones (Residuo: 0.000961)
# Poisson convergió en 2 iteraciones (Residuo: 0.000949)
# Poisson convergió en 3 iteraciones (Residuo: 0.000830)
# Poisson convergió en 3 iteraciones (Residuo: 0.000786)
# Poisson convergió en 3 iteraciones (Residuo: 0.000734)
# Poisson convergió en 2 iteraciones (Residuo: 0.000850)
# Poisson convergió en 3 iteraciones (Residuo: 0.000687)
# Poisson convergió en 3 iteraciones (Residuo: 0.000671)
# Poisson convergió en 3 iteraciones (Residuo: 0.000608)
# Poisson convergió en 2 iteraciones (Residuo: 0.000864)
# Poisson convergió en 2 iteraciones (Residuo: 0.000969)
# Paso de tiempo 9850/10000 completado.
# Poisson convergió en 3 iteraciones (Residuo: 0.000647)
# Poisson convergió en 2 iteraciones (Residuo: 0.000808)
# Poisson convergió en 2 iteraciones (Residuo: 0.000616)
# Poisson convergió en 2 iteraciones (Residuo: 0.000643)
# Poisson convergió en 2 iteraciones (Residuo: 0.000753)
# Poisson convergió en 3 iteraciones (Residuo: 0.000588)
# Poisson convergió en 3 iteraciones (Residuo: 0.000630)
# Poisson convergió en 2 iteraciones (Residuo: 0.000937)
# Poisson convergió en 3 iteraciones (Residuo: 0.000829)
# Poisson convergió en 3 iteraciones (Residuo: 0.000845)
# Poisson convergió en 3 iteraciones (Residuo: 0.000763)
# Poisson convergió en 3 iteraciones (Residuo: 0.000680)
# Poisson convergió en 2 iteraciones (Residuo: 0.000948)
# Poisson convergió en 3 iteraciones (Residuo: 0.000580)
# Poisson convergió en 2 iteraciones (Residuo: 0.000977)
# Poisson convergió en 3 iteraciones (Residuo: 0.000677)
# Poisson convergió en 3 iteraciones (Residuo: 0.000650)
# Poisson convergió en 2 iteraciones (Residuo: 0.000934)
# Poisson convergió en 2 iteraciones (Residuo: 0.000991)
# Poisson convergió en 3 iteraciones (Residuo: 0.000908)
# Poisson convergió en 3 iteraciones (Residuo: 0.000849)
# Poisson convergió en 3 iteraciones (Residuo: 0.000743)
# Poisson convergió en 2 iteraciones (Residuo: 0.000911)
# Poisson convergió en 2 iteraciones (Residuo: 0.000901)
# Poisson convergió en 3 iteraciones (Residuo: 0.000750)
# Poisson convergió en 3 iteraciones (Residuo: 0.000677)
# Poisson convergió en 2 iteraciones (Residuo: 0.000895)
# Poisson convergió en 3 iteraciones (Residuo: 0.000574)
# Poisson convergió en 2 iteraciones (Residuo: 0.000937)
# Poisson convergió en 2 iteraciones (Residuo: 0.000955)
# Poisson convergió en 2 iteraciones (Residuo: 0.000994)
# Poisson convergió en 2 iteraciones (Residuo: 0.000970)
# Poisson convergió en 3 iteraciones (Residuo: 0.000830)
# Poisson convergió en 3 iteraciones (Residuo: 0.000719)
# Poisson convergió en 2 iteraciones (Residuo: 0.000780)
# Poisson convergió en 3 iteraciones (Residuo: 0.000649)
# Poisson convergió en 2 iteraciones (Residuo: 0.000900)
# Poisson convergió en 3 iteraciones (Residuo: 0.000569)
# Poisson convergió en 3 iteraciones (Residuo: 0.000574)
# Poisson convergió en 2 iteraciones (Residuo: 0.000950)
# Poisson convergió en 3 iteraciones (Residuo: 0.000643)
# Poisson convergió en 3 iteraciones (Residuo: 0.000639)
# Poisson convergió en 3 iteraciones (Residuo: 0.000635)
# Poisson convergió en 3 iteraciones (Residuo: 0.000614)
# Poisson convergió en 2 iteraciones (Residuo: 0.000960)
# Poisson convergió en 3 iteraciones (Residuo: 0.000574)
# Poisson convergió en 2 iteraciones (Residuo: 0.000921)
# Poisson convergió en 2 iteraciones (Residuo: 0.000925)
# Poisson convergió en 2 iteraciones (Residuo: 0.000954)
# Poisson convergió en 3 iteraciones (Residuo: 0.000786)
# Paso de tiempo 9900/10000 completado.
# Poisson convergió en 3 iteraciones (Residuo: 0.000780)
# Poisson convergió en 2 iteraciones (Residuo: 0.000996)
# Poisson convergió en 3 iteraciones (Residuo: 0.000812)
# Poisson convergió en 3 iteraciones (Residuo: 0.000803)
# Poisson convergió en 3 iteraciones (Residuo: 0.000733)
# Poisson convergió en 2 iteraciones (Residuo: 0.000882)
# Poisson convergió en 3 iteraciones (Residuo: 0.000595)
# Poisson convergió en 2 iteraciones (Residuo: 0.000938)
# Poisson convergió en 2 iteraciones (Residuo: 0.000970)
# Poisson convergió en 3 iteraciones (Residuo: 0.000699)
# Poisson convergió en 2 iteraciones (Residuo: 0.000909)
# Poisson convergió en 2 iteraciones (Residuo: 0.000864)
# Poisson convergió en 3 iteraciones (Residuo: 0.000791)
# Poisson convergió en 2 iteraciones (Residuo: 0.000940)
# Poisson convergió en 3 iteraciones (Residuo: 0.000729)
# Poisson convergió en 3 iteraciones (Residuo: 0.000701)
# Poisson convergió en 2 iteraciones (Residuo: 0.000907)
# Poisson convergió en 3 iteraciones (Residuo: 0.000631)
# Poisson convergió en 3 iteraciones (Residuo: 0.000591)
# Poisson convergió en 2 iteraciones (Residuo: 0.000883)
# Poisson convergió en 3 iteraciones (Residuo: 0.000624)
# Poisson convergió en 3 iteraciones (Residuo: 0.000612)
# Poisson convergió en 2 iteraciones (Residuo: 0.000924)
# Poisson convergió en 3 iteraciones (Residuo: 0.000581)
# Poisson convergió en 3 iteraciones (Residuo: 0.000556)
# Poisson convergió en 2 iteraciones (Residuo: 0.000890)
# Poisson convergió en 3 iteraciones (Residuo: 0.000658)
# Poisson convergió en 2 iteraciones (Residuo: 0.000960)
# Poisson convergió en 2 iteraciones (Residuo: 0.000819)
# Poisson convergió en 2 iteraciones (Residuo: 0.000975)
# Poisson convergió en 3 iteraciones (Residuo: 0.000701)
# Poisson convergió en 3 iteraciones (Residuo: 0.000631)
# Poisson convergió en 2 iteraciones (Residuo: 0.000858)
# Poisson convergió en 3 iteraciones (Residuo: 0.000636)
# Poisson convergió en 3 iteraciones (Residuo: 0.000624)
# Poisson convergió en 2 iteraciones (Residuo: 0.000957)
# Poisson convergió en 3 iteraciones (Residuo: 0.000618)
# Poisson convergió en 3 iteraciones (Residuo: 0.000581)
# Poisson convergió en 2 iteraciones (Residuo: 0.000914)
# Poisson convergió en 3 iteraciones (Residuo: 0.000640)
# Poisson convergió en 2 iteraciones (Residuo: 0.000977)
# Poisson convergió en 2 iteraciones (Residuo: 0.000827)
# Poisson convergió en 3 iteraciones (Residuo: 0.000832)
# Poisson convergió en 2 iteraciones (Residuo: 0.000959)
# Poisson convergió en 3 iteraciones (Residuo: 0.000728)
# Poisson convergió en 3 iteraciones (Residuo: 0.000733)
# Poisson convergió en 2 iteraciones (Residuo: 0.000925)
# Poisson convergió en 3 iteraciones (Residuo: 0.000703)
# Poisson convergió en 3 iteraciones (Residuo: 0.000662)
# Poisson convergió en 2 iteraciones (Residuo: 0.000795)
# Paso de tiempo 9950/10000 completado.
# Poisson convergió en 3 iteraciones (Residuo: 0.000575)
# Poisson convergió en 2 iteraciones (Residuo: 0.000949)
# Poisson convergió en 3 iteraciones (Residuo: 0.000601)
# Poisson convergió en 2 iteraciones (Residuo: 0.000973)
# Poisson convergió en 2 iteraciones (Residuo: 0.000916)
# Poisson convergió en 3 iteraciones (Residuo: 0.000841)
# Poisson convergió en 2 iteraciones (Residuo: 0.000936)
# Poisson convergió en 2 iteraciones (Residuo: 0.000868)
# Poisson convergió en 3 iteraciones (Residuo: 0.000761)
# Poisson convergió en 3 iteraciones (Residuo: 0.000719)
# Poisson convergió en 3 iteraciones (Residuo: 0.000682)
# Poisson convergió en 2 iteraciones (Residuo: 0.000950)
# Poisson convergió en 3 iteraciones (Residuo: 0.000754)
# Poisson convergió en 3 iteraciones (Residuo: 0.000711)
# Poisson convergió en 2 iteraciones (Residuo: 0.000990)
# Poisson convergió en 3 iteraciones (Residuo: 0.000573)
# Poisson convergió en 3 iteraciones (Residuo: 0.000531)
# Poisson convergió en 2 iteraciones (Residuo: 0.000827)
# Poisson convergió en 2 iteraciones (Residuo: 0.000920)
# Poisson convergió en 2 iteraciones (Residuo: 0.000936)
# Poisson convergió en 3 iteraciones (Residuo: 0.000834)
# Poisson convergió en 2 iteraciones (Residuo: 0.000982)
# Poisson convergió en 3 iteraciones (Residuo: 0.000790)
# Poisson convergió en 3 iteraciones (Residuo: 0.000802)
# Poisson convergió en 2 iteraciones (Residuo: 0.000989)
# Poisson convergió en 3 iteraciones (Residuo: 0.000808)
# Poisson convergió en 3 iteraciones (Residuo: 0.000765)
# Poisson convergió en 3 iteraciones (Residuo: 0.000685)
# Poisson convergió en 2 iteraciones (Residuo: 0.000864)
# Poisson convergió en 2 iteraciones (Residuo: 0.000989)
# Poisson convergió en 3 iteraciones (Residuo: 0.000744)
# Poisson convergió en 3 iteraciones (Residuo: 0.000646)
# Poisson convergió en 2 iteraciones (Residuo: 0.000963)
# Poisson convergió en 3 iteraciones (Residuo: 0.000799)
# Poisson convergió en 3 iteraciones (Residuo: 0.000817)
# Poisson convergió en 3 iteraciones (Residuo: 0.000755)
# Poisson convergió en 3 iteraciones (Residuo: 0.000684)
# Poisson convergió en 3 iteraciones (Residuo: 0.000575)
# Poisson convergió en 2 iteraciones (Residuo: 0.000969)
# Poisson convergió en 2 iteraciones (Residuo: 0.000942)
# Poisson convergió en 2 iteraciones (Residuo: 0.000945)
# Poisson convergió en 2 iteraciones (Residuo: 0.000954)
# Poisson convergió en 3 iteraciones (Residuo: 0.000734)
# Poisson convergió en 3 iteraciones (Residuo: 0.000590)
# Poisson convergió en 2 iteraciones (Residuo: 0.000735)
# Poisson convergió en 2 iteraciones (Residuo: 0.000881)
# Poisson convergió en 3 iteraciones (Residuo: 0.000643)
# Poisson convergió en 3 iteraciones (Residuo: 0.000573)
# Poisson convergió en 2 iteraciones (Residuo: 0.000940)
# ¡Simulación terminada!
